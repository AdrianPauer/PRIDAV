# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianPauer/PRIDAV/blob/main/Films-Factors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# !git clone https://github.com/AdrianPauer/PRIDAV
# Out:
# Cloning into 'PRIDAV'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 33 (delta 0), reused 1 (delta 0), pack-reused 30
# Receiving objects: 100% (33/33), 56.76 MiB | 15.83 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %% [markdown]
# ##Dáta

# %%
ratings = pd.read_table('PRIDAV/title_ratings_scraped.tsv', delimiter='\t', na_values = '\\N')
basic = pd.read_table('PRIDAV/title_basics_scraped.tsv', delimiter='\t', na_values = '\\N')
akas = pd.read_table('PRIDAV/title_akas_scraped.tsv', delimiter='\t', na_values = '\\N')
crew = pd.read_table('PRIDAV/title_crew_scraped.tsv', delimiter='\t', na_values = '\\N')
principals = pd.read_table('PRIDAV/title_principals_scraped.tsv', delimiter='\t', na_values = '\\N')
persons = pd.read_table('PRIDAV/name_basics_scraped.tsv', delimiter='\t', na_values = '\\N')

# %%
titles = pd.merge(pd.merge(basic,crew, on = 'tconst'),ratings, on = 'tconst')
titles
# Out:
#            tconst  titleType                 primaryTitle  startYear  \
# 0       tt0000001      short                   Carmencita     1894.0
# 1       tt0000011      short      Akrobatisches Potpourri     1895.0
# 2       tt0000022      short             Blacksmith Scene     1895.0
# 3       tt0000032      short        Die Serpentintänzerin     1895.0
# 4       tt0000042      short   Bateau-mouche sur la Seine     1896.0
# ...           ...        ...                          ...        ...
# 138209  tt9916120  tvEpisode  The Evolution of the Bellas     2019.0
# 138210  tt9916220  tvEpisode    Episode dated 18 May 1988     1988.0
# 138211  tt9916428      movie          The Secret of China     2019.0
# 138212  tt9916578  tvEpisode    The Trial of Joan Collins     2019.0
# 138213  tt9916766  tvEpisode               Episode #10.15     2019.0
#
#         runtimeMinutes                       genres  directors  \
# 0                  1.0            Documentary,Short  nm0005690
# 1                  1.0            Documentary,Short  nm0804434
# 2                  1.0            Documentary,Short  nm0525910
# 3                  1.0                        Short  nm0804434
# 4                  NaN            Documentary,Short  nm0617588
# ...                ...                          ...        ...
# 138209             NaN                   Reality-TV        NaN
# 138210             NaN      Crime,Documentary,Drama        NaN
# 138211             NaN        Adventure,History,War  nm0910951
# 138212            44.0   Adventure,Biography,Comedy  nm0373673
# 138213            43.0  Family,Game-Show,Reality-TV        NaN
#
#                                         writers  averageRating  numVotes
# 0                                           NaN            5.7      2009
# 1                                           NaN            5.2       378
# 2                                           NaN            5.1      1117
# 3                                           NaN            5.0       428
# 4                                           NaN            4.1        38
# ...                                         ...            ...       ...
# 138209                                      NaN            5.2        13
# 138210                                      NaN            7.2        23
# 138211                                      NaN            3.5        17
# 138212  nm1485603,nm1485604,nm1866876,nm0909144            7.4        47
# 138213                                      NaN            7.0        22
#
# [138214 rows x 10 columns]

# %%
# kto co robil v danom filme
principals
# Out:
#             tconst      nconst         category                      job  \
# 0        tt0000001   nm1588970             self                      NaN
# 1        tt0000001   nm0005690         director                      NaN
# 2        tt0000001   nm0374658  cinematographer  director of photography
# 3        tt0000011   nm3692297            actor                      NaN
# 4        tt0000011   nm0804434         director                      NaN
# ...            ...         ...              ...                      ...
# 1150158  tt9916766   nm2563178         producer                 producer
# 1150159  tt9916766  nm11673614         producer                 producer
# 1150160  tt9916766  nm11673613         producer                 producer
# 1150161  tt9916766   nm5559308         producer                 producer
# 1150162  tt9916766   nm1416195         composer                      NaN
#
#            characters
# 0            ["Self"]
# 1                 NaN
# 2                 NaN
# 3        ["Acrobats"]
# 4                 NaN
# ...               ...
# 1150158           NaN
# 1150159           NaN
# 1150160           NaN
# 1150161           NaN
# 1150162           NaN
#
# [1150163 rows x 5 columns]

# %%
akas
# Out:
#           titleId                      title region language
# 0       tt0000001                 Карменсіта     UA      NaN
# 1       tt0000001                 Carmencita     DE      NaN
# 2       tt0000001  Carmencita - spanyol tánc     HU      NaN
# 3       tt0000001                 Καρμενσίτα     GR      NaN
# 4       tt0000001                 Карменсита     RU      NaN
# ...           ...                        ...    ...      ...
# 459984  tt9916766            Episodio #10.15     IT       it
# 459985  tt9916766               Folge #10.15     DE       de
# 459986  tt9916766            Episódio #10.15     PT       pt
# 459987  tt9916766              एपिसोड #10.15     IN       hi
# 459988  tt9916766             Épisode #10.15     FR       fr
#
# [459989 rows x 4 columns]

# %%
# ludia pre nconst
persons
# Out:
#            nconst              primaryName  birthYear  \
# 0       nm0000001             Fred Astaire     1899.0
# 1       nm0000002            Lauren Bacall     1924.0
# 2       nm0000003          Brigitte Bardot     1934.0
# 3       nm0000004             John Belushi     1949.0
# 4       nm0000005           Ingmar Bergman     1918.0
# ...           ...                      ...        ...
# 501021  nm9993410           John Branfield        NaN
# 501022  nm9993445        Hiroyuki Ishiguro        NaN
# 501023  nm9993475  Juan Sebastián Chamorro        NaN
# 501024  nm9993693              Apsara Rani     1996.0
# 501025  nm9993713            Sambit Mishra        NaN
#
#                           primaryProfession  \
# 0            soundtrack,actor,miscellaneous
# 1                        actress,soundtrack
# 2       actress,soundtrack,music_department
# 3                   actor,soundtrack,writer
# 4                     writer,director,actor
# ...                                     ...
# 501021                               writer
# 501022                             producer
# 501023                                  NaN
# 501024                              actress
# 501025                      writer,producer
#
#                                      knownForTitles
# 0           tt0031983,tt0050419,tt0053137,tt0072308
# 1           tt0037382,tt0117057,tt0075213,tt0038355
# 2           tt0054452,tt0049189,tt0057345,tt0056404
# 3           tt0072562,tt0080455,tt0077975,tt0078723
# 4           tt0083922,tt0050976,tt0050986,tt0069467
# ...                                             ...
# 501021                                    tt1687457
# 501022               tt13651628,tt8969878,tt8747870
# 501023                          tt0123338,tt1244649
# 501024    tt8302382,tt13847502,tt8737752,tt12856788
# 501025  tt15134202,tt10709066,tt27191658,tt20319332
#
# [501026 rows x 5 columns]

# %%
sns.heatmap(titles.isna(),yticklabels = False,cbar=False,cmap = 'viridis') #heatmap of missing values (yellow = NaN)
# Out:
# <Axes: >
